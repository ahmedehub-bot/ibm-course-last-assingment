# %% [markdown]
# this is done for the  last assignment for Ibm course.
#
#
# the study will include searching for the dstribution of the gym in city of Toronto and apartment building to choose the best place to open a new gym in city in  the area where there is apartment buildings but not gyms.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'Y4M4YNU0SNLVNZIMALKRKWQGL50V33YOYYNJQIQJEDUX3R2U' # your Foursquare ID
CLIENT_SECRET = 'ZTROPQOVP5KEZY3AT3SJRTBNK4DNKDWIRDS1E41SPDH0RQTD' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: Y4M4YNU0SNLVNZIMALKRKWQGL50V33YOYYNJQIQJEDUX3R2U
# CLIENT_SECRET:ZTROPQOVP5KEZY3AT3SJRTBNK4DNKDWIRDS1E41SPDH0RQTD

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %%
search_query = 'gym'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# gym .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=Y4M4YNU0SNLVNZIMALKRKWQGL50V33YOYYNJQIQJEDUX3R2U&client_secret=ZTROPQOVP5KEZY3AT3SJRTBNK4DNKDWIRDS1E41SPDH0RQTD&ll=43.653963,-79.387207&v=20180604&query=gym&radius=50000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dd7ecf7b9a389001b3cfddc'},
#  'response': {'venues': [{'id': '5133f680e4b02e871367c60c',
#     'name': 'The Gym at the Shangri-La',
#     'location': {'lat': 43.648773826131794,
#      'lng': -79.38651748319191,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648773826131794,
#        'lng': -79.38651748319191}],
#      'distance': 580,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4cd044c29d87224bf129543b',
#     'name': 'University Centre Gym',
#     'location': {'lat': 43.653571,
#      'lng': -79.386979,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653571,
#        'lng': -79.386979}],
#      'distance': 47,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4f61e092e4b0d7325fb1f8a3',
#     'name': 'Hilton Gym',
#     'location': {'address': '145 Richmond Street W',
#      'crossStreet': 'at University Ave.',
#      'lat': 43.649994452305684,
#      'lng': -79.38572977553609,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649994452305684,
#        'lng': -79.38572977553609}],
#      'distance': 457,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['145 Richmond Street W (at University Ave.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '514898c3e4b0f2687d7c083a',
#     'name': 'Gym',
#     'location': {'address': 'CBC',
#      'lat': 43.64512029038736,
#      'lng': -79.38725885086012,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64512029038736,
#        'lng': -79.38725885086012}],
#      'distance': 984,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['CBC', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#       'name': 'Athletics & Sports',
#       'pluralName': 'Athletics & Sports',
#       'shortName': 'Athletics & Sports',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4c2630ca5c5ca59364a545fe',
#     'name': 'The Matrix Gym (City Place)',
#     'location': {'address': '373 Front St. W.',
#      'crossStreet': 'Blue Jays Way',
#      'lat': 43.64291316865826,
#      'lng': -79.39246179974084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64291316865826,
#        'lng': -79.39246179974084}],
#      'distance': 1300,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['373 Front St. W. (Blue Jays Way)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '506a1889e4b05fc962888176',
#     'name': 'Gym',
#     'location': {'address': 'Hilton Garden Inn',
#      'lat': 43.657393165279096,
#      'lng': -79.37396347496728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657393165279096,
#        'lng': -79.37396347496728}],
#      'distance': 1132,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Hilton Garden Inn', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '58fb6a1e029a555d117e0cb2',
#     'name': 'The Gym',
#     'location': {'address': '181 Wellington St W',
#      'crossStreet': 'John St',
#      'lat': 43.645418,
#      'lng': -79.387059,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645418,
#        'lng': -79.387059}],
#      'distance': 951,
#      'postalCode': 'M5V 3G7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['181 Wellington St W (John St)',
#       'Toronto ON M5V 3G7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4e63c422e4cdf1e2bfdecaed',
#     'name': '1 King West Gym',
#     'location': {'address': '1 king street west',
#      'lat': 43.64874179478857,
#      'lng': -79.3780591452993,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64874179478857,
#        'lng': -79.3780591452993}],
#      'distance': 938,
#      'postalCode': 'M5H 1A1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 king street west',
#       'Toronto ON M5H 1A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4d2cac2df7a9224b252f1aa0',
#     'name': 'WestinWORKOUT Gym',
#     'location': {'address': 'The Westin Harbour Castle',
#      'crossStreet': '1 Harbour Sq',
#      'lat': 43.64054365805462,
#      'lng': -79.37594834079205,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64054365805462,
#        'lng': -79.37594834079205}],
#      'distance': 1747,
#      'postalCode': 'M5J 1A6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['The Westin Harbour Castle (1 Harbour Sq)',
#       'Toronto ON M5J 1A6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4c3a6302edba95218b98d625',
#     'name': 'Neill-Wycik (Gym)',
#     'location': {'address': '96 Gerrard St. 2nd Floor',
#      'crossStreet': 'Church',
#      'lat': 43.66058119366082,
#      'lng': -79.37755968307269,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66058119366082,
#        'lng': -79.37755968307269}],
#      'distance': 1070,
#      'postalCode': 'm5b1g7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['96 Gerrard St. 2nd Floor (Church)',
#       'Toronto ON m5b1g7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '5acaa051acb00b15aad8c42a',
#     'name': 'Keep Cool Gym',
#     'location': {'address': '530 Yonge Street',
#      'crossStreet': 'Wellesley Street',
#      'lat': 43.664118,
#      'lng': -79.384396,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.664118,
#        'lng': -79.384396}],
#      'distance': 1152,
#      'postalCode': 'M4Y 1Y8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['530 Yonge Street (Wellesley Street)',
#       'Toronto ON M4Y 1Y8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '52a67f11498ef4fe3300dc82',
#     'name': 'Gym Primrose Residence Toronto',
#     'location': {'address': '111 Carlton St',
#      'lat': 43.663429,
#      'lng': -79.37491,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.663429,
#        'lng': -79.37491}],
#      'distance': 1446,
#      'postalCode': 'M5B 2G3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['111 Carlton St', 'Toronto ON M5B 2G3', 'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4d1d4fc35c4ca1cd0a57863d',
#     'name': 'Gym at Neo',
#     'location': {'address': '15 Fort York Boulevard',
#      'lat': 43.64101768689203,
#      'lng': -79.39414045048323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64101768689203,
#        'lng': -79.39414045048323}],
#      'distance': 1545,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['15 Fort York Boulevard', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4b857d16f964a5202a6131e3',
#     'name': 'Rogers Gym',
#     'location': {'address': '1 Mount Pleasant Rd.',
#      'crossStreet': 'Jarvis Street',
#      'lat': 43.67039022999334,
#      'lng': -79.3800103502179,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67039022999334,
#        'lng': -79.3800103502179}],
#      'distance': 1918,
#      'postalCode': 'M4Y 2Y5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Mount Pleasant Rd. (Jarvis Street)',
#       'Toronto ON M4Y 2Y5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '516acb78498e109d0a305de8',
#     'name': 'Private Gym',
#     'location': {'address': 'Bay X Bloor',
#      'lat': 43.667754,
#      'lng': -79.389838,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.667754,
#        'lng': -79.389838}],
#      'distance': 1549,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Bay X Bloor', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4d3d48c4d625224bfe4d98fa',
#     'name': '1101 Bay Gym',
#     'location': {'address': '1101 Bay St',
#      'crossStreet': 'S of Bay St.',
#      'lat': 43.66786265901939,
#      'lng': -79.3877208835492,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66786265901939,
#        'lng': -79.3877208835492}],
#      'distance': 1547,
#      'postalCode': 'M5S 2W8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1101 Bay St (S of Bay St.)',
#       'Toronto ON M5S 2W8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '521b322b11d2f5c54855328d',
#     'name': 'Tridel Rêve Gym',
#     'location': {'lat': 43.641537770429416,
#      'lng': -79.39993054516387,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.641537770429416,
#        'lng': -79.39993054516387}],
#      'distance': 1721,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '55ed96b8498efde41a818a4d',
#     'name': 'Fort York Gym',
#     'location': {'address': '85 Queens Wharf Road',
#      'crossStreet': 'Bathurst',
#      'lat': 43.63858661737946,
#      'lng': -79.39862823607541,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63858661737946,
#        'lng': -79.39862823607541}],
#      'distance': 1943,
#      'postalCode': 'M5V 0J9',
#      'cc': 'CA',
#      'city': 'TORONO',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['85 Queens Wharf Road (Bathurst)',
#       'TORONO ON M5V 0J9',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a2e',
#       'name': 'Sports Club',
#       'pluralName': 'Sports Clubs',
#       'shortName': 'Sports Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4f438d9ee4b0899cce4de986',
#     'name': 'Casa Gym',
#     'location': {'address': '33 Charles St. E',
#      'lat': 43.668489826709234,
#      'lng': -79.38445815761312,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.668489826709234,
#        'lng': -79.38445815761312}],
#      'distance': 1632,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['33 Charles St. E', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4b61ec19f964a5207d2b2ae3',
#     'name': 'The Gym At Medcan',
#     'location': {'lat': 43.64935207716159,
#      'lng': -79.38429200760056,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64935207716159,
#        'lng': -79.38429200760056}],
#      'distance': 564,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4e21b1fe62e1964dbb6981cc',
#     'name': 'Richmond Gym',
#     'location': {'address': '300 Richmond St. E',
#      'crossStreet': 'Sherbourne St.',
#      'lat': 43.65348501456459,
#      'lng': -79.36741587811944,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65348501456459,
#        'lng': -79.36741587811944}],
#      'distance': 1594,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['300 Richmond St. E (Sherbourne St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '5325c1c9498e8e967d1b7816',
#     'name': 'Gym',
#     'location': {'address': '140 Simcoe Street',
#      'crossStreet': 'Richmond',
#      'lat': 43.64961242675781,
#      'lng': -79.38681030273438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64961242675781,
#        'lng': -79.38681030273438}],
#      'distance': 485,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['140 Simcoe Street (Richmond)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '5ae9b2aac53093002c337fd2',
#     'name': 'One Bloor Gym',
#     'location': {'address': '1 Bloor St E.',
#      'crossStreet': 'Yonge St',
#      'lat': 43.67008969391817,
#      'lng': -79.38650383473933,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67008969391817,
#        'lng': -79.38650383473933}],
#      'distance': 1796,
#      'postalCode': 'M4W 0A8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Bloor St E. (Yonge St)',
#       'Toronto ON M4W 0A8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4c91511d238c6dcb010ebf55',
#     'name': 'Manulife Residences Gym',
#     'location': {'address': '44 charles st west',
#      'crossStreet': 'Bay',
#      'lat': 43.668440594272326,
#      'lng': -79.38810223574656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.668440594272326,
#        'lng': -79.38810223574656}],
#      'distance': 1613,
#      'postalCode': 'M4y 1r7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['44 charles st west (Bay)',
#       'Toronto ON M4y 1r7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4d191e7185fc6dcbcdbeba4e',
#     'name': 'Gym at the Courtyard by Mariott',
#     'location': {'address': '475 Yonge St',
#      'crossStreet': 'Wood',
#      'lat': 43.66240164115153,
#      'lng': -79.38319016270458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66240164115153,
#        'lng': -79.38319016270458}],
#      'distance': 993,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['475 Yonge St (Wood)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '54229196498e92c87216e7e8',
#     'name': 'The Gym @ Motion',
#     'location': {'lat': 43.655452423207244,
#      'lng': -79.38411388057392,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655452423207244,
#        'lng': -79.38411388057392}],
#      'distance': 299,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4bd4304ba8b3a593145d6b5f',
#     'name': 'Citysphere Gym',
#     'location': {'address': '801 King W, Roof Garden',
#      'crossStreet': 'Bathurst',
#      'lat': 43.64311617696398,
#      'lng': -79.4068991873084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64311617696398,
#        'lng': -79.4068991873084}],
#      'distance': 1993,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['801 King W, Roof Garden (Bathurst)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '56dd0059498e597073ae321f',
#     'name': 'Gym @ OPL',
#     'location': {'address': '280 Simcoe St',
#      'lat': 43.65624958873613,
#      'lng': -79.39025527031475,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65624958873613,
#        'lng': -79.39025527031475}],
#      'distance': 353,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['280 Simcoe St', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4ed43175775b45f6ed272dd4',
#     'name': 'Gym',
#     'location': {'lat': 43.6555475986606,
#      'lng': -79.37647093755488,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6555475986606,
#        'lng': -79.37647093755488}],
#      'distance': 882,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False},
#    {'id': '4df69e4ec65b87473b04e0af',
#     'name': 'Gym @ Jazz',
#     'location': {'address': '167 Church St',
#      'crossStreet': 'Shuter',
#      'lat': 43.654293273868795,
#      'lng': -79.37553324398377,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654293273868795,
#        'lng': -79.37553324398377}],
#      'distance': 940,
#      'postalCode': 'M5B 1Y6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['167 Church St (Shuter)',
#       'Toronto ON M5B 1Y6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432002',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
# 1  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
# 3  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...    False
# 4  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
#
#                          id       location.address location.cc location.city  \
# 0  5133f680e4b02e871367c60c                    NaN          CA           NaN
# 1  4cd044c29d87224bf129543b                    NaN          CA           NaN
# 2  4f61e092e4b0d7325fb1f8a3  145 Richmond Street W          CA       Toronto
# 3  514898c3e4b0f2687d7c083a                    CBC          CA       Toronto
# 4  4c2630ca5c5ca59364a545fe       373 Front St. W.          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                580
# 1           Canada                  NaN                 47
# 2           Canada   at University Ave.                457
# 3           Canada                  NaN                984
# 4           Canada        Blue Jays Way               1300
#
#                            location.formattedAddress  \
# 0                                           [Canada]
# 1                                           [Canada]
# 2  [145 Richmond Street W (at University Ave.), T...
# 3                          [CBC, Toronto ON, Canada]
# 4  [373 Front St. W. (Blue Jays Way), Toronto ON,...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.64877382613179...     43.648774
# 1  [{'label': 'display', 'lat': 43.653571, 'lng':...     43.653571
# 2  [{'label': 'display', 'lat': 43.64999445230568...     43.649994
# 3  [{'label': 'display', 'lat': 43.64512029038736...     43.645120
# 4  [{'label': 'display', 'lat': 43.64291316865826...     43.642913
#
#    location.lng location.postalCode location.state  \
# 0    -79.386517                 NaN            NaN
# 1    -79.386979                 NaN            NaN
# 2    -79.385730                 NaN             ON
# 3    -79.387259                 NaN             ON
# 4    -79.392462                 NaN             ON
#
#                           name    referralId
# 0    The Gym at the Shangri-La  v-1574432002
# 1        University Centre Gym  v-1574432002
# 2                   Hilton Gym  v-1574432002
# 3                          Gym  v-1574432002
# 4  The Matrix Gym (City Place)  v-1574432002

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                name                                categories  \
# 0         The Gym at the Shangri-La                                       Gym
# 1             University Centre Gym                      Gym / Fitness Center
# 2                        Hilton Gym                                       Gym
# 3                               Gym                        Athletics & Sports
# 4       The Matrix Gym (City Place)                                       Gym
# 5                               Gym                      Gym / Fitness Center
# 6                           The Gym                      Gym / Fitness Center
# 7                   1 King West Gym                                       Gym
# 8                 WestinWORKOUT Gym                                       Gym
# 9                 Neill-Wycik (Gym)                                       Gym
# 10                    Keep Cool Gym                      Gym / Fitness Center
# 11   Gym Primrose Residence Toronto  Residential Building (Apartment / Condo)
# 12                       Gym at Neo                                       Gym
# 13                       Rogers Gym                                       Gym
# 14                      Private Gym                                       Gym
# 15                     1101 Bay Gym                                       Gym
# 16                  Tridel Rêve Gym                      Gym / Fitness Center
# 17                    Fort York Gym                               Sports Club
# 18                         Casa Gym                                       Gym
# 19                The Gym At Medcan                                       Gym
# 20                     Richmond Gym                                       Gym
# 21                              Gym                                       Gym
# 22                    One Bloor Gym                      Gym / Fitness Center
# 23          Manulife Residences Gym                      Gym / Fitness Center
# 24  Gym at the Courtyard by Mariott                      Gym / Fitness Center
# 25                 The Gym @ Motion  Residential Building (Apartment / Condo)
# 26                   Citysphere Gym                      Gym / Fitness Center
# 27                        Gym @ OPL  Residential Building (Apartment / Condo)
# 28                              Gym                                       Gym
# 29                       Gym @ Jazz                                       Gym
#
#                       address  cc     city country         crossStreet  \
# 0                         NaN  CA      NaN  Canada                 NaN
# 1                         NaN  CA      NaN  Canada                 NaN
# 2       145 Richmond Street W  CA  Toronto  Canada  at University Ave.
# 3                         CBC  CA  Toronto  Canada                 NaN
# 4            373 Front St. W.  CA  Toronto  Canada       Blue Jays Way
# 5           Hilton Garden Inn  CA  Toronto  Canada                 NaN
# 6         181 Wellington St W  CA  Toronto  Canada             John St
# 7          1 king street west  CA  Toronto  Canada                 NaN
# 8   The Westin Harbour Castle  CA  Toronto  Canada        1 Harbour Sq
# 9    96 Gerrard St. 2nd Floor  CA  Toronto  Canada              Church
# 10           530 Yonge Street  CA  Toronto  Canada    Wellesley Street
# 11             111 Carlton St  CA  Toronto  Canada                 NaN
# 12     15 Fort York Boulevard  CA  Toronto  Canada                 NaN
# 13       1 Mount Pleasant Rd.  CA  Toronto  Canada       Jarvis Street
# 14                Bay X Bloor  CA  Toronto  Canada                 NaN
# 15                1101 Bay St  CA  Toronto  Canada        S of Bay St.
# 16                        NaN  CA  Toronto  Canada                 NaN
# 17       85 Queens Wharf Road  CA   TORONO  Canada            Bathurst
# 18           33 Charles St. E  CA  Toronto  Canada                 NaN
# 19                        NaN  CA  Toronto  Canada                 NaN
# 20         300 Richmond St. E  CA  Toronto  Canada      Sherbourne St.
# 21          140 Simcoe Street  CA  Toronto  Canada            Richmond
# 22              1 Bloor St E.  CA  Toronto  Canada            Yonge St
# 23         44 charles st west  CA  Toronto  Canada                 Bay
# 24               475 Yonge St  CA  Toronto  Canada                Wood
# 25                        NaN  CA      NaN  Canada                 NaN
# 26    801 King W, Roof Garden  CA  Toronto  Canada            Bathurst
# 27              280 Simcoe St  CA  Toronto  Canada                 NaN
# 28                        NaN  CA  Toronto  Canada                 NaN
# 29              167 Church St  CA  Toronto  Canada              Shuter
#
#     distance                                   formattedAddress  \
# 0        580                                           [Canada]
# 1         47                                           [Canada]
# 2        457  [145 Richmond Street W (at University Ave.), T...
# 3        984                          [CBC, Toronto ON, Canada]
# 4       1300  [373 Front St. W. (Blue Jays Way), Toronto ON,...
# 5       1132            [Hilton Garden Inn, Toronto ON, Canada]
# 6        951  [181 Wellington St W (John St), Toronto ON M5V...
# 7        938   [1 king street west, Toronto ON M5H 1A1, Canada]
# 8       1747  [The Westin Harbour Castle (1 Harbour Sq), Tor...
# 9       1070  [96 Gerrard St. 2nd Floor (Church), Toronto ON...
# 10      1152  [530 Yonge Street (Wellesley Street), Toronto ...
# 11      1446       [111 Carlton St, Toronto ON M5B 2G3, Canada]
# 12      1545       [15 Fort York Boulevard, Toronto ON, Canada]
# 13      1918  [1 Mount Pleasant Rd. (Jarvis Street), Toronto...
# 14      1549                  [Bay X Bloor, Toronto ON, Canada]
# 15      1547  [1101 Bay St (S of Bay St.), Toronto ON M5S 2W...
# 16      1721                               [Toronto ON, Canada]
# 17      1943  [85 Queens Wharf Road (Bathurst), TORONO ON M5...
# 18      1632             [33 Charles St. E, Toronto ON, Canada]
# 19       564                               [Toronto ON, Canada]
# 20      1594  [300 Richmond St. E (Sherbourne St.), Toronto ...
# 21       485  [140 Simcoe Street (Richmond), Toronto ON, Can...
# 22      1796  [1 Bloor St E. (Yonge St), Toronto ON M4W 0A8,...
# 23      1613  [44 charles st west (Bay), Toronto ON M4y 1r7,...
# 24       993          [475 Yonge St (Wood), Toronto ON, Canada]
# 25       299                                           [Canada]
# 26      1993  [801 King W, Roof Garden (Bathurst), Toronto O...
# 27       353                [280 Simcoe St, Toronto ON, Canada]
# 28       882                               [Toronto ON, Canada]
# 29       940  [167 Church St (Shuter), Toronto ON M5B 1Y6, C...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.64877382613179...  43.648774 -79.386517
# 1   [{'label': 'display', 'lat': 43.653571, 'lng':...  43.653571 -79.386979
# 2   [{'label': 'display', 'lat': 43.64999445230568...  43.649994 -79.385730
# 3   [{'label': 'display', 'lat': 43.64512029038736...  43.645120 -79.387259
# 4   [{'label': 'display', 'lat': 43.64291316865826...  43.642913 -79.392462
# 5   [{'label': 'display', 'lat': 43.65739316527909...  43.657393 -79.373963
# 6   [{'label': 'display', 'lat': 43.645418, 'lng':...  43.645418 -79.387059
# 7   [{'label': 'display', 'lat': 43.64874179478857...  43.648742 -79.378059
# 8   [{'label': 'display', 'lat': 43.64054365805462...  43.640544 -79.375948
# 9   [{'label': 'display', 'lat': 43.66058119366082...  43.660581 -79.377560
# 10  [{'label': 'display', 'lat': 43.664118, 'lng':...  43.664118 -79.384396
# 11  [{'label': 'display', 'lat': 43.663429, 'lng':...  43.663429 -79.374910
# 12  [{'label': 'display', 'lat': 43.64101768689203...  43.641018 -79.394140
# 13  [{'label': 'display', 'lat': 43.67039022999334...  43.670390 -79.380010
# 14  [{'label': 'display', 'lat': 43.667754, 'lng':...  43.667754 -79.389838
# 15  [{'label': 'display', 'lat': 43.66786265901939...  43.667863 -79.387721
# 16  [{'label': 'display', 'lat': 43.64153777042941...  43.641538 -79.399931
# 17  [{'label': 'display', 'lat': 43.63858661737946...  43.638587 -79.398628
# 18  [{'label': 'display', 'lat': 43.66848982670923...  43.668490 -79.384458
# 19  [{'label': 'display', 'lat': 43.64935207716159...  43.649352 -79.384292
# 20  [{'label': 'display', 'lat': 43.65348501456459...  43.653485 -79.367416
# 21  [{'label': 'display', 'lat': 43.64961242675781...  43.649612 -79.386810
# 22  [{'label': 'display', 'lat': 43.67008969391817...  43.670090 -79.386504
# 23  [{'label': 'display', 'lat': 43.66844059427232...  43.668441 -79.388102
# 24  [{'label': 'display', 'lat': 43.66240164115153...  43.662402 -79.383190
# 25  [{'label': 'display', 'lat': 43.65545242320724...  43.655452 -79.384114
# 26  [{'label': 'display', 'lat': 43.64311617696398...  43.643116 -79.406899
# 27  [{'label': 'display', 'lat': 43.65624958873613...  43.656250 -79.390255
# 28  [{'label': 'display', 'lat': 43.6555475986606,...  43.655548 -79.376471
# 29  [{'label': 'display', 'lat': 43.65429327386879...  43.654293 -79.375533
#
#    postalCode state                        id
# 0         NaN   NaN  5133f680e4b02e871367c60c
# 1         NaN   NaN  4cd044c29d87224bf129543b
# 2         NaN    ON  4f61e092e4b0d7325fb1f8a3
# 3         NaN    ON  514898c3e4b0f2687d7c083a
# 4         NaN    ON  4c2630ca5c5ca59364a545fe
# 5         NaN    ON  506a1889e4b05fc962888176
# 6     M5V 3G7    ON  58fb6a1e029a555d117e0cb2
# 7     M5H 1A1    ON  4e63c422e4cdf1e2bfdecaed
# 8     M5J 1A6    ON  4d2cac2df7a9224b252f1aa0
# 9      m5b1g7    ON  4c3a6302edba95218b98d625
# 10    M4Y 1Y8    ON  5acaa051acb00b15aad8c42a
# 11    M5B 2G3    ON  52a67f11498ef4fe3300dc82
# 12        NaN    ON  4d1d4fc35c4ca1cd0a57863d
# 13    M4Y 2Y5    ON  4b857d16f964a5202a6131e3
# 14        NaN    ON  516acb78498e109d0a305de8
# 15    M5S 2W8    ON  4d3d48c4d625224bfe4d98fa
# 16        NaN    ON  521b322b11d2f5c54855328d
# 17    M5V 0J9    ON  55ed96b8498efde41a818a4d
# 18        NaN    ON  4f438d9ee4b0899cce4de986
# 19        NaN    ON  4b61ec19f964a5207d2b2ae3
# 20        NaN    ON  4e21b1fe62e1964dbb6981cc
# 21        NaN    ON  5325c1c9498e8e967d1b7816
# 22    M4W 0A8    ON  5ae9b2aac53093002c337fd2
# 23    M4y 1r7    ON  4c91511d238c6dcb010ebf55
# 24        NaN    ON  4d191e7185fc6dcbcdbeba4e
# 25        NaN   NaN  54229196498e92c87216e7e8
# 26        NaN    ON  4bd4304ba8b3a593145d6b5f
# 27        NaN    ON  56dd0059498e597073ae321f
# 28        NaN    ON  4ed43175775b45f6ed272dd4
# 29    M5B 1Y6    ON  4df69e4ec65b87473b04e0af

# %%
dataframe_filtered.head()
# Out:
#                           name            categories                address  \
# 0    The Gym at the Shangri-La                   Gym                    NaN
# 1        University Centre Gym  Gym / Fitness Center                    NaN
# 2                   Hilton Gym                   Gym  145 Richmond Street W
# 3                          Gym    Athletics & Sports                    CBC
# 4  The Matrix Gym (City Place)                   Gym       373 Front St. W.
#
#    cc     city country         crossStreet  distance  \
# 0  CA      NaN  Canada                 NaN       580
# 1  CA      NaN  Canada                 NaN        47
# 2  CA  Toronto  Canada  at University Ave.       457
# 3  CA  Toronto  Canada                 NaN       984
# 4  CA  Toronto  Canada       Blue Jays Way      1300
#
#                                     formattedAddress  \
# 0                                           [Canada]
# 1                                           [Canada]
# 2  [145 Richmond Street W (at University Ave.), T...
# 3                          [CBC, Toronto ON, Canada]
# 4  [373 Front St. W. (Blue Jays Way), Toronto ON,...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.64877382613179...  43.648774 -79.386517
# 1  [{'label': 'display', 'lat': 43.653571, 'lng':...  43.653571 -79.386979
# 2  [{'label': 'display', 'lat': 43.64999445230568...  43.649994 -79.385730
# 3  [{'label': 'display', 'lat': 43.64512029038736...  43.645120 -79.387259
# 4  [{'label': 'display', 'lat': 43.64291316865826...  43.642913 -79.392462
#
#   postalCode state                        id
# 0        NaN   NaN  5133f680e4b02e871367c60c
# 1        NaN   NaN  4cd044c29d87224bf129543b
# 2        NaN    ON  4f61e092e4b0d7325fb1f8a3
# 3        NaN    ON  514898c3e4b0f2687d7c083a
# 4        NaN    ON  4c2630ca5c5ca59364a545fe

# %% [markdown]
# this map  shows the distribution of gyms in Toronto

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel


for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4d2cac2df7a9224b252f1aa0' # ID of westen workout
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4d2cac2df7a9224b252f1aa0?client_id=Y4M4YNU0SNLVNZIMALKRKWQGL50V33YOYYNJQIQJEDUX3R2U&client_secret=ZTROPQOVP5KEZY3AT3SJRTBNK4DNKDWIRDS1E41SPDH0RQTD&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4d2cac2df7a9224b252f1aa0',
#  'name': 'WestinWORKOUT Gym',
#  'contact': {'phone': '4168691600',
#   'formattedPhone': '(416) 869-1600',
#   'twitter': 'westintoronto'},
#  'location': {'address': 'The Westin Harbour Castle',
#   'crossStreet': '1 Harbour Sq',
#   'lat': 43.64054365805462,
#   'lng': -79.37594834079205,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.64054365805462,
#     'lng': -79.37594834079205}],
#   'postalCode': 'M5J 1A6',
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['The Westin Harbour Castle (1 Harbour Sq)',
#    'Toronto ON M5J 1A6',
#    'Canada']},
#  'canonicalUrl': 'https://foursquare.com/v/westinworkout-gym/4d2cac2df7a9224b252f1aa0',
#  'categories': [{'id': '4bf58dd8d48988d176941735',
#    'name': 'Gym',
#    'pluralName': 'Gyms',
#    'shortName': 'Gym',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d175941735',
#    'name': 'Gym / Fitness Center',
#    'pluralName': 'Gyms or Fitness Centers',
#    'shortName': 'Gym / Fitness',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#     'suffix': '.png'}}],
#  'verified': False,
#  'stats': {'tipCount': 2},
#  'likes': {'count': 9,
#   'groups': [{'type': 'others',
#     'count': 9,
#     'items': [{'id': '74507043',
#       'firstName': 'ℛミミℳ',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/-R1ZGQBVVURXTGM0R.jpg'}},
#      {'id': '395117035',
#       'firstName': 'Roland',
#       'lastName': 'Torres',
#       'gender': 'male',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/blank_boy.png',
#        'default': True}},
#      {'id': '7006',
#       'firstName': 'William',
#       'lastName': 'A.',
#       'gender': 'male',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/7006_X9xdAyJM_h5GsWGE5ZlUgQGah5Qo7SckBV69VpIdhfeXamdFldP5Tz7XS53hBfBuFUzmBWhqL.jpg'}},
#      {'id': '5614435',
#       'firstName': 'Jake',
#       'lastName': 'Dylan',
#       'gender': 'male',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/5614435-OGA2G1NRNPFTEOKW.jpg'}}]}],
#   'summary': '9 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 6.2,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 16,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 1,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 1,
#     'items': [{'id': '59975272f8cbd46f1c226a06',
#       'createdAt': 1503089266,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#       'width': 3888,
#       'height': 2592,
#       'user': {'id': '212169387',
#        'firstName': 'pivot_photos',
#        'gender': 'none',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/blank_boy.png',
#         'default': True},
#        'type': 'page'},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 1,
#   'summary': 'One other person is here',
#   'groups': [{'type': 'others',
#     'name': 'Other people here',
#     'count': 1,
#     'items': []}]},
#  'createdAt': 1294773293,
#  'tips': {'count': 2,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 2,
#     'items': [{'id': '51df2252498e1e3cb88780e5',
#       'createdAt': 1373577810,
#       'text': 'Great gym for a hotel, lots of machines and good sized weight area.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/51df2252498e1e3cb88780e5',
#       'lang': 'en',
#       'likes': {'count': 3,
#        'groups': [{'type': 'others',
#          'count': 3,
#          'items': [{'id': '22911702',
#            'firstName': 'Rod',
#            'lastName': 'Lee',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/M3CP3UWKYUBPQNNM.jpg'}},
#           {'id': '43305822',
#            'firstName': 'Jorge',
#            'lastName': 'Morales',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/43305822-IIDCKK3IKVX3MRUR.jpg'}},
#           {'id': '963547',
#            'firstName': 'Dayne',
#            'lastName': 'Grant',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/5CCKMLNRUFPE3YCQ.jpg'}}]}],
#        'summary': '3 likes'},
#       'logView': True,
#       'agreeCount': 3,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '12567508',
#        'firstName': 'Robert',
#        'lastName': 'Fortier',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/12567508-S2AYCZT3ZVBAZGYF.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/fMJvnO',
#  'timeZone': 'America/Toronto',
#  'listed': {'count': 0,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 0,
#     'items': []}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '6:00 AM–11:00 AM'},
#      {'renderedTime': '1:00 PM–3:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–9:00 AM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#      {'renderedTime': '11:00 AM–Noon'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '6:00 AM–Noon'},
#      {'renderedTime': '4:00 PM–Midnight'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '6:00 AM–11:00 AM'},
#      {'renderedTime': '2:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '6:00 AM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '6:00 AM–11:00 AM'},
#      {'renderedTime': '1:00 PM–2:00 PM'},
#      {'renderedTime': '5:00 PM–7:00 PM'},
#      {'renderedTime': '9:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4ad4c05bf964a5209bf520e3',
#   'name': 'The Westin Harbour Castle, Toronto',
#   'location': {'address': '1 Harbour Square',
#    'crossStreet': 'at Bay St',
#    'lat': 43.64121139206991,
#    'lng': -79.37574863433838,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.64121139206991,
#      'lng': -79.37574863433838}],
#    'postalCode': 'M5J 1A6',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['1 Harbour Square (at Bay St)',
#     'Toronto ON M5J 1A6',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d1fa931735',
#     'name': 'Hotel',
#     'pluralName': 'Hotels',
#     'shortName': 'Hotel',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': 'The Westin Harbour Castle, Toronto',
#    'lang': 'en',
#    'id': '4ad4c05bf964a5209bf520e3',
#    'canonicalUrl': 'https://foursquare.com/v/the-westin-harbour-castle-toronto/4ad4c05bf964a5209bf520e3'}],
#  'attributes': {'groups': [{'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'No Credit Cards',
#     'count': 5,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'No'}]}]},
#  'bestPhoto': {'id': '59975272f8cbd46f1c226a06',
#   'createdAt': 1503089266,
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/212169387_C2-Wh9iB-a9yFzkkMFUuT3RsxV7Rna5lQWhqCNs0Bds.jpg',
#   'width': 3888,
#   'height': 2592,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '59975272f8cbd46f1c226a06',
#    'value': -14145480},
#   'highlightTextColor': {'photoId': '59975272f8cbd46f1c226a06', 'value': -1},
#   'algoVersion': 3}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.2

# %%
search_query = 'apartment'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# apartment .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=Y4M4YNU0SNLVNZIMALKRKWQGL50V33YOYYNJQIQJEDUX3R2U&client_secret=ZTROPQOVP5KEZY3AT3SJRTBNK4DNKDWIRDS1E41SPDH0RQTD&ll=43.653963,-79.387207&v=20180604&query=apartment&radius=50000&limit=30'

# %%
results_residential = requests.get(url).json()
results_residential
# Out:
# {'meta': {'code': 200, 'requestId': '5dd7ecfd14a126001b619c1d'},
#  'response': {'venues': [{'id': '5dd4cb3a93de6b00081ddb98',
#     'name': 'Apartment',
#     'location': {'lat': 43.646183,
#      'lng': -79.37693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646183,
#        'lng': -79.37693}],
#      'distance': 1198,
#      'postalCode': 'M5E 0A6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5E 0A6', 'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '5364e2f6498e2cafa29810aa',
#     'name': 'Financial District Furnished Apartment',
#     'location': {'address': '73 Richmond St. West',
#      'lat': 43.6508178710938,
#      'lng': -79.3825588226318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6508178710938,
#        'lng': -79.3825588226318}],
#      'distance': 512,
#      'postalCode': 'M5H 1Z4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['73 Richmond St. West',
#       'Toronto ON M5H 1Z4',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '5dd3206d4e5a2b0008ded559',
#     'name': 'The Apartment',
#     'location': {'address': '238 Queen Street East',
#      'crossStreet': 'Queen and Sherbourne',
#      'lat': 43.654736,
#      'lng': -79.36865,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654736,
#        'lng': -79.36865}],
#      'distance': 1497,
#      'postalCode': 'M5A 1S3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['238 Queen Street East (Queen and Sherbourne)',
#       'Toronto ON M5A 1S3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4fca7852e4b0c116823a6344',
#     'name': "Lieutenant-Governors Apartment - Queen's Park",
#     'location': {'lat': 43.66229767427558,
#      'lng': -79.38695645451529,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66229767427558,
#        'lng': -79.38695645451529}],
#      'distance': 928,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d12a941735',
#       'name': 'Capitol Building',
#       'pluralName': 'Capitol Buildings',
#       'shortName': 'Capitol Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_capitolbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4e040bb0b61c7592ae6e588b',
#     'name': 'University Apartment',
#     'location': {'address': '16 willison sq',
#      'crossStreet': 'spandina AVe',
#      'lat': 43.65216840171611,
#      'lng': -79.3988206459418,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65216840171611,
#        'lng': -79.3988206459418}],
#      'distance': 956,
#      'postalCode': 'M5T 1E8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['16 willison sq (spandina AVe)',
#       'Toronto ON M5T 1E8',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4ad4c05bf964a5209df520e3',
#     'name': 'Alexandra Apartment Hotel',
#     'location': {'address': '77 Ryerson Ave',
#      'lat': 43.650060530500525,
#      'lng': -79.40266875914209,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650060530500525,
#        'lng': -79.40266875914209}],
#      'distance': 1318,
#      'postalCode': 'M5T 2V4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['77 Ryerson Ave', 'Toronto ON M5T 2V4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '5633e92b498ea61bed39e5a8',
#     'name': "Ahil's Apartment",
#     'location': {'lat': 43.66392238830782,
#      'lng': -79.40274022258575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66392238830782,
#        'lng': -79.40274022258575}],
#      'distance': 1671,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '55921ad9498eac424b83ef9d',
#     'name': 'Executive Underground Apartment',
#     'location': {'lat': 43.66460709453357,
#      'lng': -79.37435939462422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66460709453357,
#        'lng': -79.37435939462422}],
#      'distance': 1573,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fb931735',
#       'name': 'Motel',
#       'pluralName': 'Motels',
#       'shortName': 'Motel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4e6ed00e1520a936fa5a69b7',
#     'name': 'Alexey Apartment',
#     'location': {'address': '105, Isabella street, #1003',
#      'crossStreet': 'Ted Rogers street',
#      'lat': 43.66824206187538,
#      'lng': -79.3794127205118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66824206187538,
#        'lng': -79.3794127205118}],
#      'distance': 1708,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['105, Isabella street, #1003 (Ted Rogers street)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '542cc75a498e68715daf6f88',
#     'name': "Mark's Downtown Apartment",
#     'location': {'address': '822-65 Scadding Avenue',
#      'lat': 43.648552,
#      'lng': -79.364645,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648552,
#        'lng': -79.364645}],
#      'distance': 1914,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['822-65 Scadding Avenue', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '5d53b16c66378f0008e1d91f',
#     'name': 'Furnished Apartment Rentals Toronto',
#     'location': {'address': '99 Yorkville Ave #200',
#      'lat': 43.670833233733866,
#      'lng': -79.39188916236162,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.670833233733866,
#        'lng': -79.39188916236162}],
#      'distance': 1915,
#      'postalCode': 'M5R 1C1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['99 Yorkville Ave #200',
#       'Toronto ON M5R 1C1',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4d8d54b6ca75b60c3df1e6a8',
#     'name': "Sean Trevor Joseph's Apartment",
#     'location': {'address': '540 Sherborne St.',
#      'lat': 43.669363,
#      'lng': -79.37582,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.669363,
#        'lng': -79.37582}],
#      'distance': 1944,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['540 Sherborne St.', 'Toronto ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4ad4c05ef964a520aef620e3',
#     'name': 'Cabbagetown',
#     'location': {'lat': 43.664276867286574,
#      'lng': -79.36796948464222,
#      'distance': 1928,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4f2a25ac4b909258e854f55f',
#       'name': 'Neighborhood',
#       'pluralName': 'Neighborhoods',
#       'shortName': 'Neighborhood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '5503658c498e74610f7b1203',
#     'name': 'RodXtein Apartment',
#     'location': {'address': '650 Parliament Street',
#      'crossStreet': 'Wellesley',
#      'lat': 43.669737133992065,
#      'lng': -79.37192336214176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.669737133992065,
#        'lng': -79.37192336214176}],
#      'distance': 2144,
#      'postalCode': 'M4X 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['650 Parliament Street (Wellesley)',
#       'Toronto ON M4X 1R3',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4ee1afff0e61689f533f9c81',
#     'name': "Jordi's Apartment Style Dorm",
#     'location': {'address': '277 Saint George Street',
#      'lat': 43.67328012764943,
#      'lng': -79.40228945224656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67328012764943,
#        'lng': -79.40228945224656}],
#      'distance': 2469,
#      'postalCode': 'M5R 2R1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['277 Saint George Street',
#       'Toronto ON M5R 2R1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '587258da1b36d47bd132a190',
#     'name': "Alen's Apartment",
#     'location': {'lat': 43.642075,
#      'lng': -79.423836,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642075,
#        'lng': -79.423836}],
#      'distance': 3233,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '515e285ce4b0510b074acdff',
#     'name': 'Dufferin Park Apartment',
#     'location': {'address': '919 Dufferin Street',
#      'lat': 43.65728286810229,
#      'lng': -79.43412381681532,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65728286810229,
#        'lng': -79.43412381681532}],
#      'distance': 3796,
#      'postalCode': 'M6H 4B3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['919 Dufferin Street',
#       'Toronto ON M6H 4B3',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4c9ae522db10b60ceddc966d',
#     'name': 'Elm Place Apartments',
#     'location': {'address': '222 Elm St.',
#      'crossStreet': 'Elm & Mccaul',
#      'lat': 43.656242646822356,
#      'lng': -79.3921389912557,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656242646822356,
#        'lng': -79.3921389912557}],
#      'distance': 471,
#      'postalCode': 'M5T 1K5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['222 Elm St. (Elm & Mccaul)',
#       'Toronto ON M5T 1K5',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '55079e92498eed8c510a8dcd',
#     'name': 'Epitome Apartments',
#     'location': {'address': '160 Huron Street',
#      'lat': 43.65711948776995,
#      'lng': -79.39781420777823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65711948776995,
#        'lng': -79.39781420777823}],
#      'distance': 923,
#      'postalCode': 'M5T 2B6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['160 Huron Street', 'Toronto ON M5T 2B6', 'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '582fc9cc80e1af60b2dea71e',
#     'name': 'Bunker Apartment',
#     'location': {'address': '630 St Clair av W',
#      'lat': 43.68197,
#      'lng': -79.42378,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.68197,
#        'lng': -79.42378}],
#      'distance': 4288,
#      'postalCode': 'M6G 2Y2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['630 St Clair av W',
#       'Toronto ON M6G 2Y2',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4c16b45edaf42d7f14994466',
#     'name': 'LuCliff Place Apartments',
#     'location': {'address': '77 Gerrard St.',
#      'crossStreet': 'at Bay St.',
#      'lat': 43.65820840938647,
#      'lng': -79.38555442218674,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65820840938647,
#        'lng': -79.38555442218674}],
#      'distance': 490,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['77 Gerrard St. (at Bay St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4b4fc348f964a5207a1427e3',
#     'name': '428 Queen St. East',
#     'location': {'address': '428 Queen St. East',
#      'crossStreet': 'Sackville',
#      'lat': 43.65562702388565,
#      'lng': -79.36410892974025,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65562702388565,
#        'lng': -79.36410892974025}],
#      'distance': 1869,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['428 Queen St. East (Sackville)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '514fb458e4b091941c353289',
#     'name': 'His Super Sexy Apartment!',
#     'location': {'lat': 43.69638,
#      'lng': -79.399081,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.69638,
#        'lng': -79.399081}],
#      'distance': 4817,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '56a0e3c2498ee7d5393a22de',
#     'name': '300 Front st West, Mary-am Suites - Furnished Apartments',
#     'location': {'address': '300 Front Street West',
#      'lat': 43.64508171979899,
#      'lng': -79.39295768737793,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64508171979899,
#        'lng': -79.39295768737793}],
#      'distance': 1091,
#      'postalCode': 'M5V 0E9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['300 Front Street West',
#       'Toronto ON M5V 0E9',
#       'Canada']},
#     'categories': [{'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'shortName': 'Business Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4e4fcb33d22daf51d27a4891',
#     'name': 'My Apartment - Winona',
#     'location': {'lat': 43.689592,
#      'lng': -79.434386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.689592,
#        'lng': -79.434386}],
#      'distance': 5491,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '5d5b1dabd9cf6e00085d5e56',
#     'name': 'Avenue Park Apartments',
#     'location': {'address': '103 Avenue Road',
#      'lat': 43.67253,
#      'lng': -79.395359,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67253,
#        'lng': -79.395359}],
#      'distance': 2168,
#      'postalCode': 'M5R 2G5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['103 Avenue Road', 'Toronto ON M5R 2G5', 'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '51d31905498ec56e9db4c3ce',
#     'name': 'The Chelsea Apartment Building',
#     'location': {'address': '62 Roehampton Ave',
#      'crossStreet': 'Bunting rd',
#      'lat': 43.708447,
#      'lng': -79.3966341,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.708447,
#        'lng': -79.3966341}],
#      'distance': 6112,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['62 Roehampton Ave (Bunting rd)', 'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '52d484cc498e27305ac68e44',
#     'name': 'Allan Plaza Apartments',
#     'location': {'address': '166 Carlton Street',
#      'lat': 43.663463206521826,
#      'lng': -79.37357305253785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.663463206521826,
#        'lng': -79.37357305253785}],
#      'distance': 1524,
#      'postalCode': 'M5A 2K5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['166 Carlton Street',
#       'Toronto ON M5A 2K5',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4de2a06dd22d2a4ecdcabd70',
#     'name': "Acacia's Amusingly Awesome Apartment",
#     'location': {'address': '207 High Park Ave',
#      'crossStreet': 'Humberside',
#      'lat': 43.661002,
#      'lng': -79.468076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.661002,
#        'lng': -79.468076}],
#      'distance': 6559,
#      'postalCode': 'M6P 2S5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['207 High Park Ave (Humberside)',
#       'Toronto ON M6P 2S5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False},
#    {'id': '4cd43a408e5b6a313e8c73ac',
#     'name': 'CAPREIT Toronto Apartments - 88 Isabella Street',
#     'location': {'address': '88 Isabella Street',
#      'crossStreet': 'Jarvis and Isabella',
#      'lat': 43.668513,
#      'lng': -79.38141528,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.668513,
#        'lng': -79.38141528}],
#      'distance': 1685,
#      'postalCode': 'M4Y 1N4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['88 Isabella Street (Jarvis and Isabella)',
#       'Toronto ON M4Y 1N4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574432004',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results_residential['response']['venues']

# tranform venues into a dataframe
dataframe_residential = json_normalize(venues)
dataframe_residential.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 1                                                 []    False
# 2  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d12a941735', 'name': 'C...    False
# 4  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
#
#                          id       location.address location.cc location.city  \
# 0  5dd4cb3a93de6b00081ddb98                    NaN          CA       Toronto
# 1  5364e2f6498e2cafa29810aa   73 Richmond St. West          CA       Toronto
# 2  5dd3206d4e5a2b0008ded559  238 Queen Street East          CA       Toronto
# 3  4fca7852e4b0c116823a6344                    NaN          CA           NaN
# 4  4e040bb0b61c7592ae6e588b         16 willison sq          CA       Toronto
#
#   location.country  location.crossStreet  location.distance  \
# 0           Canada                   NaN               1198
# 1           Canada                   NaN                512
# 2           Canada  Queen and Sherbourne               1497
# 3           Canada                   NaN                928
# 4           Canada          spandina AVe                956
#
#                            location.formattedAddress  \
# 0                       [Toronto ON M5E 0A6, Canada]
# 1  [73 Richmond St. West, Toronto ON M5H 1Z4, Can...
# 2  [238 Queen Street East (Queen and Sherbourne),...
# 3                                           [Canada]
# 4  [16 willison sq (spandina AVe), Toronto ON M5T...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.646183, 'lng':...     43.646183
# 1  [{'label': 'display', 'lat': 43.6508178710938,...     43.650818
# 2  [{'label': 'display', 'lat': 43.654736, 'lng':...     43.654736
# 3  [{'label': 'display', 'lat': 43.66229767427558...     43.662298
# 4  [{'label': 'display', 'lat': 43.65216840171611...     43.652168
#
#    location.lng location.postalCode location.state  \
# 0    -79.376930             M5E 0A6             ON
# 1    -79.382559             M5H 1Z4             ON
# 2    -79.368650             M5A 1S3             ON
# 3    -79.386956                 NaN            NaN
# 4    -79.398821             M5T 1E8             ON
#
#                                             name    referralId
# 0                                      Apartment  v-1574432004
# 1         Financial District Furnished Apartment  v-1574432004
# 2                                  The Apartment  v-1574432004
# 3  Lieutenant-Governors Apartment - Queen's Park  v-1574432004
# 4                           University Apartment  v-1574432004

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_residential_columns = ['name', 'categories'] + [col for col in dataframe_residential.columns if col.startswith('location.')] + ['id']
dataframe_residential_filtered = dataframe_residential.loc[:, filtered_residential_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_residential_filtered['categories'] = dataframe_residential_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_residential_filtered.columns = [column.split('.')[-1] for column in dataframe_residential_filtered.columns]

dataframe_residential_filtered
# Out:
#                                                  name  \
# 0                                           Apartment
# 1              Financial District Furnished Apartment
# 2                                       The Apartment
# 3       Lieutenant-Governors Apartment - Queen's Park
# 4                                University Apartment
# 5                           Alexandra Apartment Hotel
# 6                                    Ahil's Apartment
# 7                     Executive Underground Apartment
# 8                                    Alexey Apartment
# 9                           Mark's Downtown Apartment
# 10                Furnished Apartment Rentals Toronto
# 11                     Sean Trevor Joseph's Apartment
# 12                                        Cabbagetown
# 13                                 RodXtein Apartment
# 14                       Jordi's Apartment Style Dorm
# 15                                   Alen's Apartment
# 16                            Dufferin Park Apartment
# 17                               Elm Place Apartments
# 18                                 Epitome Apartments
# 19                                   Bunker Apartment
# 20                           LuCliff Place Apartments
# 21                                 428 Queen St. East
# 22                          His Super Sexy Apartment!
# 23  300 Front st West, Mary-am Suites - Furnished ...
# 24                              My Apartment - Winona
# 25                             Avenue Park Apartments
# 26                     The Chelsea Apartment Building
# 27                             Allan Plaza Apartments
# 28               Acacia's Amusingly Awesome Apartment
# 29    CAPREIT Toronto Apartments - 88 Isabella Street
#
#                                   categories                      address  cc  \
# 0   Residential Building (Apartment / Condo)                          NaN  CA
# 1                                       None         73 Richmond St. West  CA
# 2                     Furniture / Home Store        238 Queen Street East  CA
# 3                           Capitol Building                          NaN  CA
# 4   Residential Building (Apartment / Condo)               16 willison sq  CA
# 5                                      Hotel               77 Ryerson Ave  CA
# 6   Residential Building (Apartment / Condo)                          NaN  CA
# 7                                      Motel                          NaN  CA
# 8                                       None  105, Isabella street, #1003  CA
# 9   Residential Building (Apartment / Condo)       822-65 Scadding Avenue  CA
# 10  Residential Building (Apartment / Condo)        99 Yorkville Ave #200  CA
# 11                                      None            540 Sherborne St.  CA
# 12                              Neighborhood                          NaN  CA
# 13  Residential Building (Apartment / Condo)        650 Parliament Street  CA
# 14                                    Lounge      277 Saint George Street  CA
# 15  Residential Building (Apartment / Condo)                          NaN  CA
# 16  Residential Building (Apartment / Condo)          919 Dufferin Street  CA
# 17  Residential Building (Apartment / Condo)                  222 Elm St.  CA
# 18  Residential Building (Apartment / Condo)             160 Huron Street  CA
# 19  Residential Building (Apartment / Condo)            630 St Clair av W  CA
# 20  Residential Building (Apartment / Condo)               77 Gerrard St.  CA
# 21                                      None           428 Queen St. East  CA
# 22  Residential Building (Apartment / Condo)                          NaN  CA
# 23                          Business Service        300 Front Street West  CA
# 24                                      None                          NaN  CA
# 25  Residential Building (Apartment / Condo)              103 Avenue Road  CA
# 26  Residential Building (Apartment / Condo)            62 Roehampton Ave  CA
# 27  Residential Building (Apartment / Condo)           166 Carlton Street  CA
# 28                                Theme Park            207 High Park Ave  CA
# 29                                  Building           88 Isabella Street  CA
#
#        city country           crossStreet  distance  \
# 0   Toronto  Canada                   NaN      1198
# 1   Toronto  Canada                   NaN       512
# 2   Toronto  Canada  Queen and Sherbourne      1497
# 3       NaN  Canada                   NaN       928
# 4   Toronto  Canada          spandina AVe       956
# 5   Toronto  Canada                   NaN      1318
# 6       NaN  Canada                   NaN      1671
# 7   Toronto  Canada                   NaN      1573
# 8   Toronto  Canada     Ted Rogers street      1708
# 9   Toronto  Canada                   NaN      1914
# 10  Toronto  Canada                   NaN      1915
# 11  Toronto  Canada                   NaN      1944
# 12  Toronto  Canada                   NaN      1928
# 13  Toronto  Canada             Wellesley      2144
# 14  Toronto  Canada                   NaN      2469
# 15      NaN  Canada                   NaN      3233
# 16  Toronto  Canada                   NaN      3796
# 17  Toronto  Canada          Elm & Mccaul       471
# 18  Toronto  Canada                   NaN       923
# 19  Toronto  Canada                   NaN      4288
# 20  Toronto  Canada            at Bay St.       490
# 21  Toronto  Canada             Sackville      1869
# 22      NaN  Canada                   NaN      4817
# 23  Toronto  Canada                   NaN      1091
# 24  Toronto  Canada                   NaN      5491
# 25  Toronto  Canada                   NaN      2168
# 26      NaN  Canada            Bunting rd      6112
# 27  Toronto  Canada                   NaN      1524
# 28  Toronto  Canada            Humberside      6559
# 29  Toronto  Canada   Jarvis and Isabella      1685
#
#                                      formattedAddress  \
# 0                        [Toronto ON M5E 0A6, Canada]
# 1   [73 Richmond St. West, Toronto ON M5H 1Z4, Can...
# 2   [238 Queen Street East (Queen and Sherbourne),...
# 3                                            [Canada]
# 4   [16 willison sq (spandina AVe), Toronto ON M5T...
# 5        [77 Ryerson Ave, Toronto ON M5T 2V4, Canada]
# 6                                            [Canada]
# 7                                [Toronto ON, Canada]
# 8   [105, Isabella street, #1003 (Ted Rogers stree...
# 9        [822-65 Scadding Avenue, Toronto ON, Canada]
# 10  [99 Yorkville Ave #200, Toronto ON M5R 1C1, Ca...
# 11            [540 Sherborne St., Toronto ON, Canada]
# 12                               [Toronto ON, Canada]
# 13  [650 Parliament Street (Wellesley), Toronto ON...
# 14  [277 Saint George Street, Toronto ON M5R 2R1, ...
# 15                                           [Canada]
# 16  [919 Dufferin Street, Toronto ON M6H 4B3, Canada]
# 17  [222 Elm St. (Elm & Mccaul), Toronto ON M5T 1K...
# 18     [160 Huron Street, Toronto ON M5T 2B6, Canada]
# 19    [630 St Clair av W, Toronto ON M6G 2Y2, Canada]
# 20  [77 Gerrard St. (at Bay St.), Toronto ON, Canada]
# 21  [428 Queen St. East (Sackville), Toronto ON, C...
# 22                                           [Canada]
# 23  [300 Front Street West, Toronto ON M5V 0E9, Ca...
# 24                               [Toronto ON, Canada]
# 25      [103 Avenue Road, Toronto ON M5R 2G5, Canada]
# 26           [62 Roehampton Ave (Bunting rd), Canada]
# 27   [166 Carlton Street, Toronto ON M5A 2K5, Canada]
# 28  [207 High Park Ave (Humberside), Toronto ON M6...
# 29  [88 Isabella Street (Jarvis and Isabella), Tor...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.646183, 'lng':...  43.646183 -79.376930
# 1   [{'label': 'display', 'lat': 43.6508178710938,...  43.650818 -79.382559
# 2   [{'label': 'display', 'lat': 43.654736, 'lng':...  43.654736 -79.368650
# 3   [{'label': 'display', 'lat': 43.66229767427558...  43.662298 -79.386956
# 4   [{'label': 'display', 'lat': 43.65216840171611...  43.652168 -79.398821
# 5   [{'label': 'display', 'lat': 43.65006053050052...  43.650061 -79.402669
# 6   [{'label': 'display', 'lat': 43.66392238830782...  43.663922 -79.402740
# 7   [{'label': 'display', 'lat': 43.66460709453357...  43.664607 -79.374359
# 8   [{'label': 'display', 'lat': 43.66824206187538...  43.668242 -79.379413
# 9   [{'label': 'display', 'lat': 43.648552, 'lng':...  43.648552 -79.364645
# 10  [{'label': 'display', 'lat': 43.67083323373386...  43.670833 -79.391889
# 11  [{'label': 'display', 'lat': 43.669363, 'lng':...  43.669363 -79.375820
# 12                                                NaN  43.664277 -79.367969
# 13  [{'label': 'display', 'lat': 43.66973713399206...  43.669737 -79.371923
# 14  [{'label': 'display', 'lat': 43.67328012764943...  43.673280 -79.402289
# 15  [{'label': 'display', 'lat': 43.642075, 'lng':...  43.642075 -79.423836
# 16  [{'label': 'display', 'lat': 43.65728286810229...  43.657283 -79.434124
# 17  [{'label': 'display', 'lat': 43.65624264682235...  43.656243 -79.392139
# 18  [{'label': 'display', 'lat': 43.65711948776995...  43.657119 -79.397814
# 19  [{'label': 'display', 'lat': 43.68197, 'lng': ...  43.681970 -79.423780
# 20  [{'label': 'display', 'lat': 43.65820840938647...  43.658208 -79.385554
# 21  [{'label': 'display', 'lat': 43.65562702388565...  43.655627 -79.364109
# 22  [{'label': 'display', 'lat': 43.69638, 'lng': ...  43.696380 -79.399081
# 23  [{'label': 'display', 'lat': 43.64508171979899...  43.645082 -79.392958
# 24  [{'label': 'display', 'lat': 43.689592, 'lng':...  43.689592 -79.434386
# 25  [{'label': 'display', 'lat': 43.67253, 'lng': ...  43.672530 -79.395359
# 26  [{'label': 'display', 'lat': 43.708447, 'lng':...  43.708447 -79.396634
# 27  [{'label': 'display', 'lat': 43.66346320652182...  43.663463 -79.373573
# 28  [{'label': 'display', 'lat': 43.661002, 'lng':...  43.661002 -79.468076
# 29  [{'label': 'display', 'lat': 43.668513, 'lng':...  43.668513 -79.381415
#
#    postalCode state                        id
# 0     M5E 0A6    ON  5dd4cb3a93de6b00081ddb98
# 1     M5H 1Z4    ON  5364e2f6498e2cafa29810aa
# 2     M5A 1S3    ON  5dd3206d4e5a2b0008ded559
# 3         NaN   NaN  4fca7852e4b0c116823a6344
# 4     M5T 1E8    ON  4e040bb0b61c7592ae6e588b
# 5     M5T 2V4    ON  4ad4c05bf964a5209df520e3
# 6         NaN   NaN  5633e92b498ea61bed39e5a8
# 7         NaN    ON  55921ad9498eac424b83ef9d
# 8         NaN    ON  4e6ed00e1520a936fa5a69b7
# 9         NaN    ON  542cc75a498e68715daf6f88
# 10    M5R 1C1    ON  5d53b16c66378f0008e1d91f
# 11        NaN    ON  4d8d54b6ca75b60c3df1e6a8
# 12        NaN    ON  4ad4c05ef964a520aef620e3
# 13    M4X 1R3    ON  5503658c498e74610f7b1203
# 14    M5R 2R1    ON  4ee1afff0e61689f533f9c81
# 15        NaN   NaN  587258da1b36d47bd132a190
# 16    M6H 4B3    ON  515e285ce4b0510b074acdff
# 17    M5T 1K5    ON  4c9ae522db10b60ceddc966d
# 18    M5T 2B6    ON  55079e92498eed8c510a8dcd
# 19    M6G 2Y2    ON  582fc9cc80e1af60b2dea71e
# 20        NaN    ON  4c16b45edaf42d7f14994466
# 21        NaN    ON  4b4fc348f964a5207a1427e3
# 22        NaN   NaN  514fb458e4b091941c353289
# 23    M5V 0E9    ON  56a0e3c2498ee7d5393a22de
# 24        NaN    ON  4e4fcb33d22daf51d27a4891
# 25    M5R 2G5    ON  5d5b1dabd9cf6e00085d5e56
# 26        NaN   NaN  51d31905498ec56e9db4c3ce
# 27    M5A 2K5    ON  52d484cc498e27305ac68e44
# 28    M6P 2S5    ON  4de2a06dd22d2a4ecdcabd70
# 29    M4Y 1N4    ON  4cd43a408e5b6a313e8c73ac

# %%
dataframe_residential_filtered.head()
# Out:
#                                             name  \
# 0                                      Apartment
# 1         Financial District Furnished Apartment
# 2                                  The Apartment
# 3  Lieutenant-Governors Apartment - Queen's Park
# 4                           University Apartment
#
#                                  categories                address  cc  \
# 0  Residential Building (Apartment / Condo)                    NaN  CA
# 1                                      None   73 Richmond St. West  CA
# 2                    Furniture / Home Store  238 Queen Street East  CA
# 3                          Capitol Building                    NaN  CA
# 4  Residential Building (Apartment / Condo)         16 willison sq  CA
#
#       city country           crossStreet  distance  \
# 0  Toronto  Canada                   NaN      1198
# 1  Toronto  Canada                   NaN       512
# 2  Toronto  Canada  Queen and Sherbourne      1497
# 3      NaN  Canada                   NaN       928
# 4  Toronto  Canada          spandina AVe       956
#
#                                     formattedAddress  \
# 0                       [Toronto ON M5E 0A6, Canada]
# 1  [73 Richmond St. West, Toronto ON M5H 1Z4, Can...
# 2  [238 Queen Street East (Queen and Sherbourne),...
# 3                                           [Canada]
# 4  [16 willison sq (spandina AVe), Toronto ON M5T...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.646183, 'lng':...  43.646183 -79.376930
# 1  [{'label': 'display', 'lat': 43.6508178710938,...  43.650818 -79.382559
# 2  [{'label': 'display', 'lat': 43.654736, 'lng':...  43.654736 -79.368650
# 3  [{'label': 'display', 'lat': 43.66229767427558...  43.662298 -79.386956
# 4  [{'label': 'display', 'lat': 43.65216840171611...  43.652168 -79.398821
#
#   postalCode state                        id
# 0    M5E 0A6    ON  5dd4cb3a93de6b00081ddb98
# 1    M5H 1Z4    ON  5364e2f6498e2cafa29810aa
# 2    M5A 1S3    ON  5dd3206d4e5a2b0008ded559
# 3        NaN   NaN  4fca7852e4b0c116823a6344
# 4    M5T 1E8    ON  4e040bb0b61c7592ae6e588b

# %% [markdown]
# the map shows the distribution of apartment in Toronot

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel




for lat, lng, label in zip(dataframe_residential_filtered.lat, dataframe_residential_filtered.lng, dataframe_residential_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# bringing the two plans to compare visually .


for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# bringing the two maps in one map to visually compare the geographical data. Note the words gym and green starts with letter g
# and residential and red with r, so green for gyms and red for residential building .

# %%
# the blue dots are the gyms and the red are the residential buildings.

venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel




for lat, lng, label in zip(dataframe_residential_filtered.lat, dataframe_residential_filtered.lng, dataframe_residential_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)



for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# by naked eye we can say that the best area to open a new gym will be west part of the  city btween queen street south and bloor street north.
